# %%
import pandas as pd
df = pd.read_csv('survey_results_public.csv')
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
filt = (df['Country'] == 'India')

# %%
df[filt]
# Out:
#        ResponseId                              MainBranch          Employment  \
# 8               9          I am a developer by profession  Employed part-time
# 22             23  I am a student who is learning to code  Student, full-time
# 39             40  I am a student who is learning to code  Student, part-time
# 49             50  I am a student who is learning to code  Student, full-time
# 52             53          I am a developer by profession  Employed full-time
# ...           ...                                     ...                 ...
# 83399       83400          I am a developer by profession  Employed full-time
# 83406       83407  I am a student who is learning to code  Student, full-time
# 83410       83411  I am a student who is learning to code  Student, part-time
# 83411       83412          I am a developer by profession  Employed full-time
# 83417       83418          I am a developer by profession  Student, full-time
#
# ...

# %%
filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 83434    False
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# Name: Country, Length: 83439, dtype: bool

# %%
df[~filt]
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
high_salary = (df['ConvertedCompYearly'] > 70000)
df.loc[high_salary, ['ResponseId','Country','Age','Gender','ConvertedCompYearly']]
# Out:
#        ResponseId                   Country              Age Gender  \
# 12             13                   Germany  25-34 years old    Man
# 18             19                 Singapore  45-54 years old    Man
# 24             25                   Germany  35-44 years old    Man
# 26             27               Switzerland  25-34 years old    Man
# 31             32                    Israel  25-34 years old    Man
# ...           ...                       ...              ...    ...
# 83430       83431  United States of America  45-54 years old    Man
# 83432       83433                    Canada  18-24 years old  Woman
# 83434       83435  United States of America  25-34 years old    Man
# 83436       83437  United States of America  25-34 years old    Man
# 83437       83438                    Canada  25-34 years old    Man
#
#        ConvertedCompYearly
# 12                 77290.0
# 18                160932.0
# 24                 77831.0
# 26                 81319.0
# ...

# %%
countries = ['India', 'United States of America','Canada','Germany']
filt = df['Country'].isin(countries)
df.loc[filt, 'Country']
# Out:
# 5        United States of America
# 6        United States of America
# 8                           India
# 12                        Germany
# 15       United States of America
#                    ...
# 83430    United States of America
# 83432                      Canada
# 83434    United States of America
# 83436    United States of America
# 83437                      Canada
# Name: Country, Length: 34436, dtype: object

# %%
df.loc[filt, 'Country'].value_counts()
# Out:
# United States of America    15288
# India                       10511
# Germany                      5625
# Canada                       3012
# Name: Country, dtype: int64

# %%
pd.set_option('display.max_columns',48)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, ['ResponseId','Country','Age','Gender', 'LanguageHaveWorkedWith','ConvertedCompYearly']]
# Out:
#        ResponseId                                            Country  \
# 1               2                                        Netherlands
# 2               3                                 Russian Federation
# 4               5  United Kingdom of Great Britain and Northern I...
# 5               6                           United States of America
# 9              10                                             Sweden
# ...           ...                                                ...
# 83429       83430                           United States of America
# 83430       83431                           United States of America
# 83431       83432                                           Pakistan
# 83436       83437                           United States of America
# 83437       83438                                             Canada
#
#                    Age                      Gender  \
# 1      18-24 years old                         Man
# ...

# %%
df.loc[filt, 'Country'].value_counts()
# Out:
# United States of America                                7975
# India                                                   5233
# Germany                                                 2713
# United Kingdom of Great Britain and Northern Ireland    2149
# Canada                                                  1593
#                                                         ...
# Tuvalu                                                     1
# Chad                                                       1
# Gambia                                                     1
# Fiji                                                       1
# Niger                                                      1
# Name: Country, Length: 174, dtype: int64

# %%
df[filt]
# Out:
#        ResponseId                                         MainBranch  \
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 4               5                     I am a developer by profession
# 5               6             I am a student who is learning to code
# 9              10                     I am a developer by profession
# ...           ...                                                ...
# 83429       83430                        I code primarily as a hobby
# 83430       83431                     I am a developer by profession
# 83431       83432                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
#
#                                               Employment  \
# 1                                     Student, full-time
# ...
