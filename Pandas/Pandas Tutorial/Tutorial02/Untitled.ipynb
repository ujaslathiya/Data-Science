# %%
People = {
    "first" : ['ujas','mahek','jigar'],
    "last" : ['lathiya','khanapara','vavaliya'],
    "email" : ['ujas123@gmail.com','mahek234@gmail.com','jigar@gmail.com']
}

# %%
import pandas as pd
df = pd.DataFrame(People)
df
# Out:
#    first       last               email
# 0   ujas    lathiya   ujas123@gmail.com
# 1  mahek  khanapara  mahek234@gmail.com
# 2  jigar   vavaliya     jigar@gmail.com

# %%
df['email']
# Out:
# 0     ujas123@gmail.com
# 1    mahek234@gmail.com
# 2       jigar@gmail.com
# Name: email, dtype: object

# %%
df[['first','last']]
# Out:
#    first       last
# 0   ujas    lathiya
# 1  mahek  khanapara
# 2  jigar   vavaliya

# %%
df.email
# Out:
# 0     ujas123@gmail.com
# 1    mahek234@gmail.com
# 2       jigar@gmail.com
# Name: email, dtype: object

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.iloc[0]
# Out:
# first                 ujas
# last               lathiya
# email    ujas123@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#    first       last               email
# 0   ujas    lathiya   ujas123@gmail.com
# 1  mahek  khanapara  mahek234@gmail.com

# %%
df.iloc[[0,1], 2]
# Out:
# 0     ujas123@gmail.com
# 1    mahek234@gmail.com
# Name: email, dtype: object

# %%
df.iloc[[0,1], [0,1]]
# Out:
#    first       last
# 0   ujas    lathiya
# 1  mahek  khanapara

# %%
df.loc[[0,1],'email']
# Out:
# 0     ujas123@gmail.com
# 1    mahek234@gmail.com
# Name: email, dtype: object

# %%
df.loc[[0,1],['first','last']]
# Out:
#    first       last
# 0   ujas    lathiya
# 1  mahek  khanapara

# %%
df.loc[0:2, 'first':'email']
# Out:
#    first       last               email
# 0   ujas    lathiya   ujas123@gmail.com
# 1  mahek  khanapara  mahek234@gmail.com
# 2  jigar   vavaliya     jigar@gmail.com

# %%
public_df = pd.read_csv('survey_results_public.csv')

# %%
public_df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
pd.set_option('display.max_columns',48)

# %%
public_df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
public_df['SurveyEase']
# Out:
# 0                              Easy
# 1                              Easy
# 2                              Easy
# 3        Neither easy nor difficult
# 4                              Easy
#                     ...
# 83434                          Easy
# 83435                          Easy
# 83436    Neither easy nor difficult
# 83437    Neither easy nor difficult
# 83438                          Easy
# Name: SurveyEase, Length: 83439, dtype: object

# %%
public_df['SurveyEase'].value_counts()
# Out:
# Easy                          63087
# Neither easy nor difficult    18091
# Difficult                       770
# Name: SurveyEase, dtype: int64

# %%
public_df.loc[0:23, 'Country':'Age']
# Out:
#                                               Country       US_State  \
# 0                                            Slovakia            NaN
# 1                                         Netherlands            NaN
# 2                                  Russian Federation            NaN
# 3                                             Austria            NaN
# 4   United Kingdom of Great Britain and Northern I...            NaN
# 5                            United States of America        Georgia
# 6                            United States of America  New Hampshire
# 7                                            Malaysia            NaN
# 8                                               India            NaN
# 9                                              Sweden            NaN
# 10  United Kingdom of Great Britain and Northern I...            NaN
# 11                                              Spain            NaN
# 12                                            Germany            NaN
# ...

# %%
public_df.loc[0:23, 'Country':'Currency']
# Out:
#                                               Country       US_State  \
# 0                                            Slovakia            NaN
# 1                                         Netherlands            NaN
# 2                                  Russian Federation            NaN
# 3                                             Austria            NaN
# 4   United Kingdom of Great Britain and Northern I...            NaN
# 5                            United States of America        Georgia
# 6                            United States of America  New Hampshire
# 7                                            Malaysia            NaN
# 8                                               India            NaN
# 9                                              Sweden            NaN
# 10  United Kingdom of Great Britain and Northern I...            NaN
# 11                                              Spain            NaN
# 12                                            Germany            NaN
# ...

# %%
public_df.loc[0:23, 'Country':'Currency'].shape
# Out:
# (24, 11)
