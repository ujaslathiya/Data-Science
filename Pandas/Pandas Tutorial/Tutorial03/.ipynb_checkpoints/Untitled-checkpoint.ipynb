# %%
People = {
    "first" : ['ujas','mahek','jigar'],
    "last" : ['lathiya','khanapara','vavaliya'],
    "email" : ['ujas123@gmail.com','mahek234@gmail.com','jigar@gmail.com']
}

# %%
import pandas as pd
df = pd.DataFrame(People)
df
# Out:
#    first       last               email
# 0   ujas    lathiya   ujas123@gmail.com
# 1  mahek  khanapara  mahek234@gmail.com
# 2  jigar   vavaliya     jigar@gmail.com

# %%
df.set_index('first')
# Out:
#             last               email
# first
# ujas     lathiya   ujas123@gmail.com
# mahek  khanapara  mahek234@gmail.com
# jigar   vavaliya     jigar@gmail.com

# %%
df
# Out:
#    first       last               email
# 0   ujas    lathiya   ujas123@gmail.com
# 1  mahek  khanapara  mahek234@gmail.com
# 2  jigar   vavaliya     jigar@gmail.com

# %%
df.set_index('first', inplace=True)

# %%
df
# Out:
#             last               email
# first
# ujas     lathiya   ujas123@gmail.com
# mahek  khanapara  mahek234@gmail.com
# jigar   vavaliya     jigar@gmail.com

# %%
df.reset_index()
# Out:
#    first       last               email
# 0   ujas    lathiya   ujas123@gmail.com
# 1  mahek  khanapara  mahek234@gmail.com
# 2  jigar   vavaliya     jigar@gmail.com

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    first       last               email
# 0   ujas    lathiya   ujas123@gmail.com
# 1  mahek  khanapara  mahek234@gmail.com
# 2  jigar   vavaliya     jigar@gmail.com

# %%
public_df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
public_df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
public_df.sort_index(ascending=False)
# Out:
#                                                    MainBranch  \
# ResponseId
# 83439                          I am a developer by profession
# 83438                          I am a developer by profession
# 83437                          I am a developer by profession
# 83436                          I am a developer by profession
# 83435                          I am a developer by profession
# ...                                                       ...
# 5                              I am a developer by profession
# 4                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 2                      I am a student who is learning to code
# 1                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 83439                                      Employed full-time
# 83438                                      Employed full-time
# ...

# %%
public_df.set_index('Country',inplace=True)

# %%
public_df.sort_index()
# Out:
#                                                     MainBranch  \
# Country
# Afghanistan             I am a student who is learning to code
# Afghanistan                     I am a developer by profession
# Afghanistan                     I am a developer by profession
# Afghanistan  I am not primarily a developer, but I write co...
# Afghanistan                     I am a developer by profession
# ...                                                        ...
# Zimbabwe                        I am a developer by profession
# Zimbabwe                           I code primarily as a hobby
# Zimbabwe                        I am a developer by profession
# Zimbabwe                        I am a developer by profession
# Zimbabwe                        I am a developer by profession
#
#                                          Employment US_State UK_Country  \
# Country
# Afghanistan                      Student, part-time      NaN        NaN
# ...

# %%
public_df.sort_index(inplace=True)

# %%
public_df['Employment']
# Out:
# Country
# Afghanistan                        Student, part-time
# Afghanistan        Not employed, but looking for work
# Afghanistan                                       NaN
# Afghanistan        Not employed, but looking for work
# Afghanistan                        Employed full-time
#                                 ...
# Zimbabwe                           Employed full-time
# Zimbabwe       Not employed, and not looking for work
# Zimbabwe                           Student, part-time
# Zimbabwe                           Employed full-time
# Zimbabwe                           Employed full-time
# Name: Employment, Length: 83439, dtype: object
