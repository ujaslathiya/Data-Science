# %%
People = {
    "first" : ['ujas','mahek','jigar'],
    "last" : ['lathiya','khanapara','vavaliya'],
    "email" : ['ujas123@gmail.com','mahek234@gmail.com','jigar@gmail.com']
}

# %%
import pandas as pd
df = pd.DataFrame(People)
df
# Out:
#    first       last               email
# 0   ujas    lathiya   ujas123@gmail.com
# 1  mahek  khanapara  mahek234@gmail.com
# 2  jigar   vavaliya     jigar@gmail.com

# %%
df.rename(columns = {'first' : 'first_name', 'last':'last_name'}, inplace=True)

# %%
df
# Out:
#   first_name  last_name               email
# 0       ujas    lathiya   ujas123@gmail.com
# 1      mahek  khanapara  mahek234@gmail.com
# 2      jigar   vavaliya     jigar@gmail.com

# %%
df.loc[2, 'last_name'] = 'patel'

# %%
df
# Out:
#   first_name  last_name               email   last
# 0       ujas    lathiya   ujas123@gmail.com    NaN
# 1      mahek  khanapara  mahek234@gmail.com    NaN
# 2      jigar      patel     jigar@gmail.com  patel

# %%
filt = (df['email'] == 'jigar@gmail.com')
df.loc[filt, 'last_name'] = 'vavaliya'

# %%
df
# Out:
#   first_name  last_name               email      last
# 0       ujas    lathiya   ujas123@gmail.com       NaN
# 1      mahek  khanapara  mahek234@gmail.com       NaN
# 2      jigar   vavaliya     jigar@gmail.com  vavaliya

# %%
df['email'].str.lower()
# Out:
# 0     ujas123@gmail.com
# 1    mahek234@gmail.com
# 2       jigar@gmail.com
# Name: email, dtype: object

# %%
df['email'] = df['email'].str.upper()

# %%
df
# Out:
#   first_name  last_name               email      last
# 0       ujas    lathiya   UJAS123@GMAIL.COM       NaN
# 1      mahek  khanapara  MAHEK234@GMAIL.COM       NaN
# 2      jigar   vavaliya     JIGAR@GMAIL.COM  vavaliya

# %%
df['email'].apply(len)
# Out:
# 0    17
# 1    18
# 2    15
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.lower()

# %%
df['email'].apply(update_email)
# Out:
# 0     ujas123@gmail.com
# 1    mahek234@gmail.com
# 2       jigar@gmail.com
# Name: email, dtype: object

# %%
df
# Out:
#   first_name  last_name               email      last
# 0       ujas    lathiya   UJAS123@GMAIL.COM       NaN
# 1      mahek  khanapara  MAHEK234@GMAIL.COM       NaN
# 2      jigar   vavaliya     JIGAR@GMAIL.COM  vavaliya

# %%
df['email'] = df['email'].apply(update_email)

# %%
df
# Out:
#   first_name  last_name               email      last
# 0       ujas    lathiya   ujas123@gmail.com       NaN
# 1      mahek  khanapara  mahek234@gmail.com       NaN
# 2      jigar   vavaliya     jigar@gmail.com  vavaliya

# %%
df['email'] = df['email'].apply(lambda x: x.upper())

# %%
df
# Out:
#   first_name  last_name               email      last
# 0       ujas    lathiya   UJAS123@GMAIL.COM       NaN
# 1      mahek  khanapara  MAHEK234@GMAIL.COM       NaN
# 2      jigar   vavaliya     JIGAR@GMAIL.COM  vavaliya

# %%
df.apply(len)
# Out:
# first_name    3
# last_name     3
# email         3
# last          3
# dtype: int64

# %%
len(df['email'])
# Out:
# 3

# %%
df.apply(len, axis='columns')
# Out:
# 0    4
# 1    4
# 2    4
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df.apply(pd.Series.min)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# ...

# %%
df.apply(lambda x: x.min())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df.apply(lambda x: x.min())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# ...

# %%
df.applymap(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df.applymap(len)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:9653, in DataFrame.applymap(self, func, na_action, **kwargs)
#    9650         return lib.map_infer(x, func, ignore_na=ignore_na)
#    9651     return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
# -> 9653 return self.apply(infer).__finalize__(self, "applymap")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# ...

# %%
df = pd.DataFrame(People)

# %%
df
# Out:
#    first       last               email
# 0   ujas    lathiya   ujas123@gmail.com
# 1  mahek  khanapara  mahek234@gmail.com
# 2  jigar   vavaliya     jigar@gmail.com

# %%
df.applymap(len)
# Out:
#    first  last  email
# 0      4     7     17
# 1      5     9     18
# 2      5     8     15

# %%
df.apply(pd.Series.min)
# Out:
# first              jigar
# last           khanapara
# email    jigar@gmail.com
# dtype: object

# %%
df.apply(lambda x: x.min())
# Out:
# first              jigar
# last           khanapara
# email    jigar@gmail.com
# dtype: object

# %%
df.applymap(min)
# Out:
#   first last email
# 0     a    a     .
# 1     a    a     .
# 2     a    a     .

# %%
df.applymap(str.lower)
# Out:
#    first       last               email
# 0   ujas    lathiya   ujas123@gmail.com
# 1  mahek  khanapara  mahek234@gmail.com
# 2  jigar   vavaliya     jigar@gmail.com

# %%
df['first'].map({'ujas':'hardik', 'jigar':'ridham'})
# Out:
# 0    hardik
# 1       NaN
# 2    ridham
# Name: first, dtype: object

# %%
df['first'].replace({'ujas':'hardik','jigar':'ridham'})
# Out:
# 0    hardik
# 1     mahek
# 2    ridham
# Name: first, dtype: object

# %%
df
# Out:
#    first       last               email
# 0   ujas    lathiya   ujas123@gmail.com
# 1  mahek  khanapara  mahek234@gmail.com
# 2  jigar   vavaliya     jigar@gmail.com

# %%
df['first'] = df['first'].replace({'ujas':'hardik','jigar':'ridham'})

# %%
df
# Out:
#     first       last               email
# 0  hardik    lathiya   ujas123@gmail.com
# 1   mahek  khanapara  mahek234@gmail.com
# 2  ridham   vavaliya     jigar@gmail.com

# %%
public_df = pd.read_csv('survey_results_public.csv')

# %%
public_df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
pd.set_option('display.max_columns', 48)

# %%
public_df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
public_df.rename(columns = {'ConvertedCompYearly':'salaryUSD'}).head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
public_df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
public_df.rename(columns={'ConvertedCompYearly':'salaryUSD'}, inplace=True)

# %%
public_df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
public_df['SOAccount'].map({'Yes' : True, 'No' : False})
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 83434    False
# 83435     True
# 83436     True
# 83437     True
# 83438     True
# Name: SOAccount, Length: 83439, dtype: object

# %%
public_df['SOAccount']
# Out:
# 0        Yes
# 1        Yes
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 83434     No
# 83435    Yes
# 83436    Yes
# 83437    Yes
# 83438    Yes
# Name: SOAccount, Length: 83439, dtype: object

# %%
public_df['SOAccount'] = public_df['SOAccount'].map({'Yes' : True, 'No' : False})

# %%
public_df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...
